# %% [markdown]
# # Color Identification in Images

# %% [markdown]
# **By - Somali Pattjoshi**
#
# ~ Computer Vision Intern at The Spark Foundation

# %% [markdown]
# _____________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# **Libraries Required :**
#
#     Matplotlib
#     Numpy
#     Counter
#     OpenCV
#
# **Algorithm :**
#
#     KMeans Algorithm
#
# **To compare colors :**
#
#     rgb2lab
#     deltaE_cie76
#
# **To combine paths while reading files from a directory :**
#
#     import os

# %% [markdown]
# _____________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# **Import the required libraries**

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np
import cv2
from collections import Counter
from skimage.color import rgb2lab, deltaE_cie76
import os

# %matplotlib inline

# %% [markdown]
# **Read the Image**

# %%
image = cv2.imread('sun.jpg')
print("The type of this input is {}".format(type(image)))
print("Shape: {}".format(image.shape))
plt.imshow(image)
# Out:
# The type of this input is <class 'numpy.ndarray'>
# Shape: (183, 275, 3)

# %% [markdown]
# The color of the image looks a bit off. This is because, by default, OpenCV reads image in the sequence Blue Green Red (BGR).
#
# Thus, to view the actual image we need to convert the rendering to Red Green Blue (RGB).

# %% [markdown]
# **Represented image as a combination of three colors, Red, Blue and Green**

# %%
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %% [markdown]
# ## Color Identification

# %% [markdown]
# RGB to Hex Conversion

# %%
def RGB2HEX(color):
    return "#{:02x}{:02x}{:02x}".format(int(color[0]), int(color[1]), int(color[2]))

# %% [markdown]
# Read image in RGB color space

# %%
def get_image(image_path):
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    return image

# %% [markdown]
# Get colors from an image

# %%
modified_image = cv2.resize(image, (600, 400), interpolation = cv2.INTER_AREA)
modified_image = modified_image.reshape(modified_image.shape[0]*modified_image.shape[1], 3)

# %% [markdown]
# Implement KMeans algorithm to get number of colors

# %%
clf = KMeans(n_clusters = 6)
labels = clf.fit_predict(modified_image)

# %%
counts = Counter(labels)

center_colors = clf.cluster_centers_
# We get ordered colors by iterating through the keys
ordered_colors = [center_colors[i] for i in counts.keys()]
hex_colors = [RGB2HEX(ordered_colors[i]) for i in counts.keys()]
rgb_colors = [ordered_colors[i] for i in counts.keys()]

if (6):
    plt.figure(figsize = (8, 6))
    plt.pie(counts.values(), labels = hex_colors, colors = hex_colors)

# %% [markdown]
# Second Image

# %% [markdown]
# **Read the Image**

# %%
image1 = cv2.imread('pic2.jpeg')
print("The type of this input is {}".format(type(image1)))
print("Shape: {}".format(image1.shape))
plt.imshow(image1)
# Out:
# The type of this input is <class 'numpy.ndarray'>
# Shape: (388, 600, 3)

# %% [markdown]
# Represented image as a combination of three colors, Red, Blue and Green

# %%
image1 = cv2.cvtColor(image1, cv2.COLOR_BGR2RGB)
plt.imshow(image1)

# %% [markdown]
# # Color Identification

# %% [markdown]
# RGB to Hex Conversion

# %%
def RGB2HEX(color):
    return "#{:02x}{:02x}{:02x}".format(int(color[0]), int(color[1]), int(color[2]))

# %% [markdown]
# Read image in RGB color space

# %%
def get_image(image_path):
    image1 = cv2.imread(image_path)
    image1 = cv2.cvtColor(image1, cv2.COLOR_BGR2RGB)
    return image1

# %% [markdown]
# Get colors from an image

# %%
modified_image = cv2.resize(image1, (600, 400), interpolation = cv2.INTER_AREA)
modified_image = modified_image.reshape(modified_image.shape[0]*modified_image.shape[1], 3)

# %% [markdown]
# Implement KMeans algorithm to get number of colors

# %%
clf = KMeans(n_clusters =10 )
labels = clf.fit_predict(modified_image)

# %%
counts = Counter(labels)

center_colors = clf.cluster_centers_
# We get ordered colors by iterating through the keys
ordered_colors = [center_colors[i] for i in counts.keys()]
hex_colors = [RGB2HEX(ordered_colors[i]) for i in counts.keys()]
rgb_colors = [ordered_colors[i] for i in counts.keys()]

if (8):
    plt.figure(figsize = (8, 6))
    plt.pie(counts.values(), labels = hex_colors, colors = hex_colors)

# %% [markdown]
# _____________________________________________________________________________________________________________________________________________________________________________________
